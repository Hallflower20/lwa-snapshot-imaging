# %%
import numpy as np
import glob
import astropy
from astropy.io import fits
import os
from matplotlib import colors
import matplotlib.pyplot as plt

# %%
def plot_data(obj,percentile = [0, 99.9]):
    plt.imshow(obj, origin='lower', cmap='gray', norm=colors.LogNorm(), vmin = 0, vmax = 70)

# %%
time_stamp = "20230820_051012_73MHz"
data_location = "/fast/xhall/snapshots/tm_images/20230820_050010_73MHz/"
file = time_stamp + "-image.fits"

# %%
os.path.join(data_location, file)
# Out:
# '/fast/xhall/snapshots/tm_images/20230820_050010_73MHz/20230820_050010_73MHz-image.fits'

# %%
image = fits.open(os.path.join(data_location, file))[0].data[0][0]
#image_flag = fits.open(os.path.join(data_location, file_flag))[0].data[0][0]

# %%
plt.figure(figsize = (15,15))
plt.imshow(image, origin='lower', cmap='gray', vmin = 0, vmax = 70)
plt.colorbar()
